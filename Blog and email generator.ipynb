# %% [markdown]
# # **Blog and email generator**

# %%
pip install streamlit google-generativeai

# %%
import streamlit as st
import google.generativeai as genai
import os

# Configure Gemini API
# Check if running in Colab to use google.colab.userdata
# Otherwise, try st.secrets or st.text_input
API_KEY = ""
try:
    from google.colab import userdata
    API_KEY = userdata.get('GEMINI_API_KEY')
except ImportError:
    # Not in Colab, try Streamlit secrets or prompt user
    API_KEY = st.secrets.get("GEMINI_API_KEY", os.environ.get("GEMINI_API_KEY"))

if not API_KEY:
    st.warning("GEMINI_API_KEY not found. Please enter it below or set it in Colab secrets / Streamlit secrets.toml")
    API_KEY = st.text_input("Enter Gemini API Key", type="password", help="You can get your API key from https://makersuite.google.com/key")
    if not API_KEY:
        st.stop()

genai.configure(api_key=API_KEY)

model = genai.GenerativeModel("gemini-pro-latest") # Using gemini-pro-latest as identified earlier

st.set_page_config(page_title="AI Blog & Email Generator", layout="wide")

st.title("✍️ AI Blog & Email Generator")

content_type = st.radio(
    "Select Content Type",
    ["Blog", "Email"]
)

user_input = st.text_area(
    "Enter Topic / Purpose",
    height=120
)

tone = st.selectbox(
    "Select Tone",
    ["Professional", "Casual", "Friendly", "Technical", "Persuasive"]
)

if content_type == "Blog":
    length = st.selectbox(
        "Blog Length",
        ["500 words", "1000 words", "1500 words"]
    )

    prompt = f"""
    Generate a blog post.

    Topic: {user_input}
    Tone: {tone}
    Length: {length}

    Include:
    - SEO Friendly Title
    - Meta Description
    - Introduction
    - Headings and Subheadings
    - Conclusion
    """

else:
    prompt = f"""
    Generate a professional email.

    Purpose: {user_input}
    Tone: {tone}

    Include:
    - Subject Line
    - Greeting
    - Email Body
    - Closing
    """

if st.button("Generate"):
    with st.spinner("Generating..."):
        response = model.generate_content(prompt)

        st.subheader("Generated Content")
        st.write(response.text)

        st.download_button(
            label="Download",
            data=response.text,
            file_name=f"{content_type.lower()}.txt",
            mime="text/plain"
        )

# %%
# !streamlit run app.py

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai
import os

# Configure Gemini API
# Check if running in Colab to use google.colab.userdata
# Otherwise, try st.secrets or st.text_input
API_KEY = ""
try:
    from google.colab import userdata
    API_KEY = userdata.get('GEMINI_API_KEY')
except ImportError:
    # Not in Colab, try Streamlit secrets or prompt user
    API_KEY = st.secrets.get("GEMINI_API_KEY", os.environ.get("GEMINI_API_KEY"))

if not API_KEY:
    st.warning("GEMINI_API_KEY not found. Please enter it below or set it in Colab secrets / Streamlit secrets.toml")
    API_KEY = st.text_input("Enter Gemini API Key", type="password", help="You can get your API key from https://makersuite.google.com/key")
    if not API_KEY:
        st.stop()

genai.configure(api_key=API_KEY)

model = genai.GenerativeModel("gemini-pro-latest") # Using gemini-pro-latest as identified earlier

st.set_page_config(page_title="AI Blog & Email Generator", layout="wide")

st.title("✍️ AI Blog & Email Generator")

content_type = st.radio(
    "Select Content Type",
    ["Blog", "Email"]
)

user_input = st.text_area(
    "Enter Topic / Purpose",
    height=120
)

tone = st.selectbox(
    "Select Tone",
    ["Professional", "Casual", "Friendly", "Technical", "Persuasive"]
)

if content_type == "Blog":
    length = st.selectbox(
        "Blog Length",
        ["500 words", "1000 words", "1500 words"]
    )

    prompt = f"""
    Generate a blog post.

    Topic: {user_input}
    Tone: {tone}
    Length: {length}

    Include:
    - SEO Friendly Title
    - Meta Description
    - Introduction
    - Headings and Subheadings
    - Conclusion
    """

else:
    prompt = f"""
    Generate a professional email.

    Purpose: {user_input}
    Tone: {tone}

    Include:
    - Subject Line
    - Greeting
    - Email Body
    - Closing
    """

if st.button("Generate"):
    with st.spinner("Generating..."):
        response = model.generate_content(prompt)

        st.subheader("Generated Content")
        st.write(response.text)

        st.download_button(
            label="Download",
            data=response.text,
            file_name=f"{content_type.lower()}.txt",
            mime="text/plain"
        )
# Out:
# Writing app.py

# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata # Import userdata

# Configure Gemini API using the API key from Colab secrets
# Replace 'GEMINI_API_KEY' with the name you used in Colab secrets if it's different
API_KEY = userdata.get('GEMINI_API_KEY')

genai.configure(api_key=API_KEY)

# print("Listing available models:")
# for m in genai.list_models():
#     if "generateContent" in m.supported_generation_methods:
#         print(m.name)

model = genai.GenerativeModel("gemini-2.5-flash") # Using gemini-2.5-flash from the available list

prompt = "Write a 1000-word blog on Artificial Intelligence."

response = model.generate_content(prompt)

print(response.text)
# Out:
# ## Beyond the Code: Understanding, Harnessing, and Navigating the AI Revolution
#
# In the annals of human innovation, few advancements have captured our collective imagination and sparked as much debate as Artificial Intelligence. From the dystopian visions of sentient machines to the utopian dreams of a world free from toil and disease, AI has transcended the realm of science fiction and firmly planted itself in our daily reality. But what truly is AI, and how do we, as a society, navigate its breathtaking ascent?
#
# This isn't just about robots on assembly lines or chatbots answering customer queries; it's a profound societal shift, a new epoch demanding our attention, understanding, and responsible stewardship.
#
# **Defining the Enigma: What is Artificial Intelligence?**
#
# At its core, Artificial Intelligence refers to the simulation of human intelligence processes by machines, especially computer systems. These processes include learning (the acquisition of information and rules for using the information), reasoning (using rules to reach approximate or definite conclusions), and self-correction. It’s about building systems that can perceive, reason, learn, and act with a degree of autonomy, mimicking or even surpassing human cognitive abilities in specific domains.
#
# The journey of AI is not new. Its roots trace back to the mid-20th century with pioneers like Alan Turing, who pondered the question, "Can machines think?" Early AI, often called "symbolic AI," focused on programming explicit rules. However, the true explosion began with the advent of Machine Learning (ML) – algorithms that allow systems to learn from data without explicit programming. This evolved into Deep Learning (DL), utilizing artificial neural networks with multiple layers, mimicking the brain's structure, to process vast amounts of complex data like images, speech, and text with astonishing accuracy.
#
# **The Three Waves: From Narrow Tasks to General Intelligence (and Beyond?)**
#
# To truly grasp AI's current state and future trajectory, it's crucial to understand its classifications:
#
# 1.  **Artificial Narrow Intelligence (ANI):** This is the AI that permeates our lives today. ANI, also known as "Weak AI," is designed and trained for a particular task. Think of Siri, Alexa, Google Translate, Netflix's recommendation engine, the AI that beats chess grandmasters, or the sophisticated algorithms powering medical diagnostics. These systems excel at their specific functions but lack general cognitive abilities. They can't perform tasks outside their programmed scope, nor do they possess consciousness or self-awareness.
#
# 2.  **Artificial General Intelligence (AGI):** This is the holy grail of AI research, often referred to as "Strong AI." AGI would possess the ability to understand, learn, and apply intelligence across a wide range of problems, much like a human being. An AGI could learn any intellectual task that a human can perform, reason, solve unfamiliar problems, and even exhibit creativity. While significant progress has been made in various ANI domains, true AGI remains largely theoretical, representing a monumental leap that many experts believe is still decades away, if achievable at all.
#
# 3.  **Artificial Super Intelligence (ASI):** If AGI were to be realized, the logical (and perhaps terrifying) next step would be ASI. This refers to an intellect that is vastly superior to the best human brains in virtually every field, including scientific creativity, general wisdom, and social skills. ASI would not only be capable of human-level intelligence across all domains but would also possess the capacity for self-improvement at an exponential rate, potentially leading to an intelligence explosion. This is the realm where the biggest ethical and existential questions emerge, pushing the boundaries of what it means to be human and control our own destiny.
#
# **AI in Our Daily Lives: The Invisible Hand**
#
# While AGI and ASI reside in the future's mist, ANI is already an omnipresent force. Every time you unlock your phone with your face, get a personalized product recommendation, use GPS navigation that avoids traffic, receive an automatically generated email response, or even witness a medical scan being analyzed for abnormalities, you're interacting with ANI.
#
# In healthcare, AI is revolutionizing drug discovery, personalizing treatment plans, and aiding in early disease detection. In finance, it's detecting fraud, optimizing trading strategies, and providing personalized financial advice. In transportation, self-driving cars, though still in testing phases, rely heavily on AI to perceive, predict, and react. Environmental science uses AI to model climate change, optimize renewable energy grids, and manage waste. Even in creative fields, AI is generating art, composing music, and writing compelling narratives.
#
# **The Promise: A Future Reshaped for the Better**
#
# The potential benefits of AI are staggering. It promises to augment human capabilities, automate mundane tasks, accelerate scientific discovery, and solve some of humanity's most intractable problems.
#
# *   **Healthcare:** AI could lead to cures for currently incurable diseases, predict outbreaks, and make quality healthcare accessible globally.
# *   **Climate Change:** From smart energy grids to optimizing sustainable agriculture and monitoring deforestation, AI offers powerful tools to combat environmental degradation.
# *   **Economic Growth:** Increased efficiency, new industries, and personalized services could unlock unprecedented economic growth and improve quality of life.
# *   **Accessibility:** AI-powered assistive technologies can empower individuals with disabilities, breaking down barriers and fostering greater inclusion.
#
# **The Perils and the Ponderous Questions: Navigating the Ethical Minefield**
#
# Yet, with great power comes great responsibility. The rapid advancement of AI also presents profound ethical, social, and economic challenges that demand careful consideration and proactive solutions.
#
# *   **Bias and Fairness:** AI systems learn from data. If that data is biased (reflecting historical human prejudices), the AI will perpetuate and even amplify those biases, leading to unfair outcomes in hiring, lending, criminal justice, and more.
# *   **Job Displacement:** Automation, while boosting productivity, could displace millions of workers, necessitating massive societal investments in reskilling, education, and potentially new economic models like universal basic income.
# *   **Privacy and Surveillance:** The insatiable need for data to train AI models raises concerns about individual privacy, data security, and the potential for ubiquitous surveillance by governments and corporations.
# *   **Autonomous Weapons:** The development of "killer robots" – fully autonomous weapons systems that can select and engage targets without human intervention – presents a terrifying ethical frontier, raising questions about accountability and the very nature of war.
# *   **The "Black Box" Problem:** Many advanced AI models, particularly deep learning networks, operate as "black boxes," making it difficult for humans to understand how they arrive at their decisions. This lack of interpretability poses challenges for accountability, trust, and debugging.
# *   **Control and Safety:** As AI systems become more powerful and autonomous, ensuring they remain aligned with human values and goals becomes paramount. The "alignment problem" – ensuring AI's objectives don't inadvertently lead to catastrophic outcomes for humanity – is a critical area of research.
#
# **The Path Forward: Human-Centric AI**
#
# The AI revolution is not merely a technological one; it is a human one. Our ability to harness its immense potential while mitigating its inherent risks will define the 21st century. This requires a multi-faceted approach:
#
# *   **Ethical Frameworks and Regulation:** We need robust global frameworks, laws, and regulations that prioritize human rights, fairness, transparency, and accountability in AI development and deployment.
# *   **Education and Reskilling:** Investing in education and lifelong learning is crucial to prepare workforces for the changing job landscape, fostering skills that complement AI rather than compete with it.
# *   **Interdisciplinary Collaboration:** AI development cannot be left solely to technologists. Philosophers, ethicists, social scientists, policymakers, and the public must be integral to the conversation, ensuring AI serves all of humanity.
# *   **Transparency and Explainability:** Research efforts must focus on making AI systems more transparent and their decision-making processes more understandable to humans.
# *   **Safety and Alignment Research:** Dedicated efforts are needed to ensure AI systems are robust, secure, and designed to align with human values, preventing unintended consequences.
#
# The AI revolution is not a choice but a reality. It's a powerful tool, a mirror reflecting our data, biases, and aspirations. The future isn't about AI replacing humanity, but about AI augmenting it. Our challenge, and our greatest opportunity, is to sculpt this future with wisdom, foresight, and a steadfast commitment to human flourishing. By doing so, we can ensure that AI becomes not just a marvel of technology, but a catalyst for a more intelligent, equitable, and humane world.
